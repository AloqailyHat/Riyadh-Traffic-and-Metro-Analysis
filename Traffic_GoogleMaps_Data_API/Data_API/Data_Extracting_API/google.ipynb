# %%
### This code extract the interchange stations -whole line from start to end-

import pandas as pd
import requests
from datetime import datetime  # Import datetime module

# Define your API key
API_KEY = 'AIzaSyAF0TT32ntx3vs--O3tloq4jJyLVR_VhLQ'

# Define the base URL for Google Maps Directions API
base_url = 'https://maps.googleapis.com/maps/api/directions/json'

# List of origin-destination pairs
locations = [
    {'origin': '24.8296182,46.616385', 'destination': '24.5601699,46.7762684'},  # b11 to b35
    {'origin': '24.5601699,46.7762684', 'destination': '24.8296182,46.616385'},  # b35 to b11
    {'origin': '24.7102105,46.6283024', 'destination': '24.7930073,46.8364015'},  # r11 to r25
    {'origin': '24.7930073,46.8364015', 'destination': '24.7102105,46.6283024'},  # r25 to r11
    {'origin': '24.7674375,46.6430625', 'destination': '24.961072,46.6987871'},  # y11 to y20
    {'origin': '24.961072,46.6987871', 'destination': '24.7674375,46.6430625'},  # y20 to y11
    {'origin': '24.7674375,46.6430625', 'destination': '24.7012889,46.8298925'},  # p11 to p21
    {'origin': '24.7012889,46.8298925', 'destination': '24.7674375,46.6430625'},  # p21 to p11
    {'origin': '24.5914692,46.5433147', 'destination': '24.7221189,46.8611355'},  # o11 to o32
    {'origin': '24.7221189,46.8611355', 'destination': '24.5914692,46.5433147'},  # o32 to o11
    {'origin': '24.7406772,46.6947625', 'destination': '24.6459853,46.7146782'},  # g11 to g22
    {'origin': '24.6459853,46.7146782', 'destination': '24.7406772,46.6947625'}   # g22 to g11
]

# Initialize an empty list to store the results
results = []

# Loop through each origin-destination pair
for loc in locations:
    # Define the parameters for the request
    params = {
        'origin': loc['origin'],
        'destination': loc['destination'],
        'mode': 'driving',
        'departure_time': 'now',
        'traffic_model': 'best_guess',
        'language': 'en',
        'key': API_KEY
    }

    # Make the API request
    response = requests.get(base_url, params=params)
    directions = response.json()

    # Get the current time (local time)
    current_time = datetime.now().strftime("%H:%M")  # Format as HH:MM

    # Check if the request was successful
    if directions['status'] == 'OK':
        # Access route and leg information
        route = directions['routes'][0]['legs'][0]

        # Create a dictionary with the relevant information for each leg
        leg_info = {
            'Origin': loc['origin'],
            'Destination': loc['destination'],
            'Start Address': route['start_address'],
            'End Address': route['end_address'],
            'Distance': route['distance']['text'],
            'Duration': route['duration']['text'],
            'Request Time': current_time  # Add the request time
        }

        # Check if 'duration_in_traffic' is available
        if 'duration_in_traffic' in route:
            leg_info['Duration with Traffic'] = route['duration_in_traffic']['text']
        else:
            leg_info['Duration with Traffic'] = 'No traffic data available'

        # Append the leg's information to the results list
        results.append(leg_info)
    else:
        print(f"Error: {directions['status']} for origin: {loc['origin']} and destination: {loc['destination']}")

# Convert the results list into a DataFrame
same_line = pd.DataFrame(results)
same_line.to_csv("oneline.csv", index=False)

# %%
### This code extract the lines of the metro


import pandas as pd
import requests
from datetime import datetime  # Import datetime module

# Define your API key
API_KEY = 'AIzaSyAF0TT32ntx3vs--O3tloq4jJyLVR_VhLQ'

# Define the base URL for Google Maps Directions API
base_url = 'https://maps.googleapis.com/maps/api/directions/json'

# List of origin-destination pairs (including the new ones you provided)
locations = [

    # New set of coordinates provided
    {'origin': '24.8296182,46.616385', 'destination': '24.961072,46.6987871'},  # b11 to y20
    {'origin': '24.8296182,46.616385', 'destination': '24.7012889,46.8298925'},  # b11 to p21
    {'origin': '24.8296182,46.616385', 'destination': '24.7930073,46.8364015'},  # b11 to r25
    {'origin': '24.8296182,46.616385', 'destination': '24.7102105,46.6283024'},  # b11 to r11
    {'origin': '24.8296182,46.616385', 'destination': '24.7406772,46.6947625'},  # b11 to g11
    {'origin': '24.8296182,46.616385', 'destination': '24.6459853,46.7146782'},  # b11 to g22
    {'origin': '24.8296182,46.616385', 'destination': '24.7674375,46.6430625'},  # b11 to p11
    {'origin': '24.8296182,46.616385', 'destination': '24.7221189,46.8611355'},  # b11 to o32
    {'origin': '24.8296182,46.616385', 'destination': '24.5914692,46.5433147'},  # b11 to o11
    {'origin': '24.961072,46.6987871', 'destination': '24.7012889,46.8298925'},  # y20 to p21
    {'origin': '24.961072,46.6987871', 'destination': '24.7674375,46.6430625'},  # y20 to p11
    {'origin': '24.7674375,46.6430625', 'destination': '24.961072,46.6987871'},  # p11 to y20
    {'origin': '24.7674375,46.6430625', 'destination': '24.7930073,46.8364015'},  # p11 to r25
    {'origin': '24.7674375,46.6430625', 'destination': '24.7102105,46.6283024'},  # p11 to r11
    {'origin': '24.7674375,46.6430625', 'destination': '24.7221189,46.8611355'},  # p11 to o32
    {'origin': '24.7674375,46.6430625', 'destination': '24.5914692,46.5433147'},  # p11 to o11
    {'origin': '24.7406772,46.6947625', 'destination': '24.7930073,46.8364015'},  # g11 to r25
    {'origin': '24.7406772,46.6947625', 'destination': '24.7102105,46.6283024'},  # g11 to r11
    {'origin': '24.7406772,46.6947625', 'destination': '24.8296182,46.616385'},   # g11 to b11
    {'origin': '24.7406772,46.6947625', 'destination': '24.5601699,46.7762684'},  # g11 to b35
    {'origin': '24.5914692,46.5433147', 'destination': '24.5601699,46.7762684'},  # o11 to b35
    {'origin': '24.5914692,46.5433147', 'destination': '24.8296182,46.616385'},   # o11 to b11
    {'origin': '24.5914692,46.5433147', 'destination': '24.7674375,46.6430625'}   # o11 to p11
]

# Initialize an empty list to store the results
results = []

# Loop through each origin-destination pair
for loc in locations:
    # Define the parameters for the request
    params = {
        'origin': loc['origin'],
        'destination': loc['destination'],
        'mode': 'driving',
        'departure_time': 'now',
        'traffic_model': 'best_guess',
        'language': 'en',
        'key': API_KEY
    }

    # Make the API request
    response = requests.get(base_url, params=params)
    directions = response.json()

    # Get the current time (local time)
    current_time = datetime.now().strftime("%H:%M")  # Format as HH:MM

    # Check if the request was successful
    if directions['status'] == 'OK':
        # Access route and leg information
        route = directions['routes'][0]['legs'][0]

        # Create a dictionary with the relevant information for each leg
        leg_info = {
            'Origin': loc['origin'],
            'Destination': loc['destination'],
            'Start Address': route['start_address'],
            'End Address': route['end_address'],
            'Distance': route['distance']['text'],
            'Duration': route['duration']['text'],
            'Request Time': current_time  # Add the request time
        }

        # Check if 'duration_in_traffic' is available
        if 'duration_in_traffic' in route:
            leg_info['Duration with Traffic'] = route['duration_in_traffic']['text']
        else:
            leg_info['Duration with Traffic'] = 'No traffic data available'

        # Append the leg's information to the results list
        results.append(leg_info)
    else:
        print(f"Error: {directions['status']} for origin: {loc['origin']} and destination: {loc['destination']}")

# Convert the results list into a DataFrame
lines = pd.DataFrame(results)
lines.to_csv("lines.csv", index=False)

# %%
import pandas as pd
import requests
from datetime import datetime
import os  # To check if the file exists

# Define your API key
API_KEY = 'AIzaSyAF0TT32ntx3vs--O3tloq4jJyLVR_VhLQ'

# Define the base URL for Google Maps Directions API
base_url = 'https://maps.googleapis.com/maps/api/directions/json'

# List of origin-destination pairs (including the new ones you provided)
locations = [
    {'origin': '24.8296182,46.616385', 'destination': '24.5601699,46.7762684'},  # b11 to b35
    {'origin': '24.5601699,46.7762684', 'destination': '24.8296182,46.616385'},  # b35 to b11
    {'origin': '24.7102105,46.6283024', 'destination': '24.7930073,46.8364015'},  # r11 to r25
    {'origin': '24.7930073,46.8364015', 'destination': '24.7102105,46.6283024'},  # r25 to r11
    {'origin': '24.7674375,46.6430625', 'destination': '24.961072,46.6987871'},  # y11 to y20
    {'origin': '24.961072,46.6987871', 'destination': '24.7674375,46.6430625'},  # y20 to y11
    {'origin': '24.7674375,46.6430625', 'destination': '24.7012889,46.8298925'},  # p11 to p21
    {'origin': '24.7012889,46.8298925', 'destination': '24.7674375,46.6430625'},  # p21 to p11
    {'origin': '24.5914692,46.5433147', 'destination': '24.7221189,46.8611355'},  # o11 to o32
    {'origin': '24.7221189,46.8611355', 'destination': '24.5914692,46.5433147'},  # o32 to o11
    {'origin': '24.7406772,46.6947625', 'destination': '24.6459853,46.7146782'},  # g11 to g22
    {'origin': '24.6459853,46.7146782', 'destination': '24.7406772,46.6947625'}   # g22 to g11
]

# Initialize an empty list to store the results
results = []

# Loop through each origin-destination pair
for loc in locations:
    # Define the parameters for the request
    params = {
        'origin': loc['origin'],
        'destination': loc['destination'],
        'mode': 'driving',
        'departure_time': 'now',
        'traffic_model': 'best_guess',
        'language': 'en',
        'key': API_KEY
    }

    # Make the API request
    response = requests.get(base_url, params=params)
    directions = response.json()

    # Get the current time (local time)
    current_time = datetime.now().strftime("%H:%M")  # Format as HH:MM

    # Check if the request was successful
    if directions['status'] == 'OK':
        # Access route and leg information
        route = directions['routes'][0]['legs'][0]

        # Create a dictionary with the relevant information for each leg
        leg_info = {
            'Origin': loc['origin'],
            'Destination': loc['destination'],
            'Start Address': route['start_address'],
            'End Address': route['end_address'],
            'Distance': route['distance']['text'],
            'Duration': route['duration']['text'],
            'Request Time': current_time  # Add the request time
        }

        # Check if 'duration_in_traffic' is available
        if 'duration_in_traffic' in route:
            leg_info['Duration with Traffic'] = route['duration_in_traffic']['text']
        else:
            leg_info['Duration with Traffic'] = 'No traffic data available'

        # Append the leg's information to the results list
        results.append(leg_info)
    else:
        print(f"Error: {directions['status']} for origin: {loc['origin']} and destination: {loc['destination']}")

# Convert the results list into a DataFrame
df = pd.DataFrame(results)

# Define the CSV file name
csv_filename = 'oneline.csv'

# Check if the file exists
file_exists = os.path.isfile(csv_filename)

# Save the DataFrame to a CSV file (append mode)
df.to_csv(csv_filename, mode='a', header=not file_exists, index=False)

print(f"Results appended to {csv_filename}")
# Out:
# Results appended to oneline.csv

# %%
import pandas as pd
import requests
from datetime import datetime
import os  # To check if the file exists

# Define your API key
API_KEY = 'AIzaSyAF0TT32ntx3vs--O3tloq4jJyLVR_VhLQ'

# Define the base URL for Google Maps Directions API
base_url = 'https://maps.googleapis.com/maps/api/directions/json'

# List of origin-destination pairs (including the new ones you provided)
locations = [
    {'origin': '24.8296182,46.616385', 'destination': '24.961072,46.6987871'},  # b11 to y20
    {'origin': '24.8296182,46.616385', 'destination': '24.7012889,46.8298925'},  # b11 to p21
    {'origin': '24.8296182,46.616385', 'destination': '24.7930073,46.8364015'},  # b11 to r25
    {'origin': '24.8296182,46.616385', 'destination': '24.7102105,46.6283024'},  # b11 to r11
    {'origin': '24.8296182,46.616385', 'destination': '24.7406772,46.6947625'},  # b11 to g11
    {'origin': '24.8296182,46.616385', 'destination': '24.6459853,46.7146782'},  # b11 to g22
    {'origin': '24.8296182,46.616385', 'destination': '24.7674375,46.6430625'},  # b11 to p11
    {'origin': '24.8296182,46.616385', 'destination': '24.7221189,46.8611355'},  # b11 to o32
    {'origin': '24.8296182,46.616385', 'destination': '24.5914692,46.5433147'},  # b11 to o11
    {'origin': '24.961072,46.6987871', 'destination': '24.7012889,46.8298925'},  # y20 to p21
    {'origin': '24.961072,46.6987871', 'destination': '24.7674375,46.6430625'},  # y20 to p11
    {'origin': '24.7674375,46.6430625', 'destination': '24.961072,46.6987871'},  # p11 to y20
    {'origin': '24.7674375,46.6430625', 'destination': '24.7930073,46.8364015'},  # p11 to r25
    {'origin': '24.7674375,46.6430625', 'destination': '24.7102105,46.6283024'},  # p11 to r11
    {'origin': '24.7674375,46.6430625', 'destination': '24.7221189,46.8611355'},  # p11 to o32
    {'origin': '24.7674375,46.6430625', 'destination': '24.5914692,46.5433147'},  # p11 to o11
    {'origin': '24.7406772,46.6947625', 'destination': '24.7930073,46.8364015'},  # g11 to r25
    {'origin': '24.7406772,46.6947625', 'destination': '24.7102105,46.6283024'},  # g11 to r11
    {'origin': '24.7406772,46.6947625', 'destination': '24.8296182,46.616385'},   # g11 to b11
    {'origin': '24.7406772,46.6947625', 'destination': '24.5601699,46.7762684'},  # g11 to b35
    {'origin': '24.5914692,46.5433147', 'destination': '24.5601699,46.7762684'},  # o11 to b35
    {'origin': '24.5914692,46.5433147', 'destination': '24.8296182,46.616385'},   # o11 to b11
    {'origin': '24.5914692,46.5433147', 'destination': '24.7674375,46.6430625'}   # o11 to p11
]

# Initialize an empty list to store the results
results = []

# Loop through each origin-destination pair
for loc in locations:
    # Define the parameters for the request
    params = {
        'origin': loc['origin'],
        'destination': loc['destination'],
        'mode': 'driving',
        'departure_time': 'now',
        'traffic_model': 'best_guess',
        'language': 'en',
        'key': API_KEY
    }

    # Make the API request
    response = requests.get(base_url, params=params)
    directions = response.json()

    # Get the current time (local time)
    current_time = datetime.now().strftime("%H:%M")  # Format as HH:MM

    # Check if the request was successful
    if directions['status'] == 'OK':
        # Access route and leg information
        route = directions['routes'][0]['legs'][0]

        # Create a dictionary with the relevant information for each leg
        leg_info = {
            'Origin': loc['origin'],
            'Destination': loc['destination'],
            'Start Address': route['start_address'],
            'End Address': route['end_address'],
            'Distance': route['distance']['text'],
            'Duration': route['duration']['text'],
            'Request Time': current_time  # Add the request time
        }

        # Check if 'duration_in_traffic' is available
        if 'duration_in_traffic' in route:
            leg_info['Duration with Traffic'] = route['duration_in_traffic']['text']
        else:
            leg_info['Duration with Traffic'] = 'No traffic data available'

        # Append the leg's information to the results list
        results.append(leg_info)
    else:
        print(f"Error: {directions['status']} for origin: {loc['origin']} and destination: {loc['destination']}")

# Convert the results list into a DataFrame
df = pd.DataFrame(results)

# Define the CSV file name
csv_filename = 'lines.csv'

# Check if the file exists
file_exists = os.path.isfile(csv_filename)

# Save the DataFrame to a CSV file (append mode)
df.to_csv(csv_filename, mode='a', header=not file_exists, index=False)

print(f"Results appended to {csv_filename}")
# Out:
# Results appended to lines.csv
